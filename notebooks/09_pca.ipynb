# %% [markdown]
# Let's examine discrete PCA. See how quickly eigenvalues decay, directions of greatest variance, association between these and the response, etc.

# %% [markdown]
# Don't forget to go back to the 07_permuted notebook and just permute the columns! Hopefully this shows that only FLR breaks down, which suggests that FLR *really* assumes smoothness.
